# %% [markdown]
# <a href="https://colab.research.google.com/github/dydytn/Test_Test/blob/main/Unit_Total.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **單元 A 學習重點**
# *   **特殊函數介紹**
# *   **s i n 與 c o s 之疊合**
# *   **指數與對數函數圖形**

# %% [markdown]
# ## **A01.我的第一個python程式**

# %%
#我的第一個python程式
print("Welcome to Tnssh!")

# %% [markdown]
# ## **A02.基本數據類型**

# %%
#基本數據類型
x=2021     #整數
y="Tnssh"    #字串
z=1.23     #浮點數

print(x)    #會換行
print(y)    #會換行
print(z)    #會換行
print(" ")   #會空一行

print(x,end=" ") #不換行
print(y,end=" ") #不換行
print(z,end=" ") #不換行

# %% [markdown]
# ## **A03.整數的算術運算**
#
# 以 , 作間隔 , 多運用 print 指令,可檢查程式是否有誤~

# %%
#整數的算術運算
a =13
b =10

print(a,"+",b,"=",a+b)
print(a,"-",b,"=",a-b)
print(a,"*",b,"=",a*b)
print(a,"/",b,"=",a/b)
print("a除以b取整數值=",int(a/b))
print("a除以b取商數=",a//b)
print("a除以b取餘數=",a%b)
print("a的b次方=",a**b)

# %% [markdown]
# ## **A04.特殊函數 : 絕對值,正弦,餘弦,對數**
#
#
# ![m03.png](data:image/png;base64,...)

# %%
import numpy as np
pi=3.14159 #圓周率
x1=-5
x2=60*pi/180
x3=30*pi/180
x4=0.001

y1=abs(x1)
y2=np.sin(x2)
y3=np.cos(x3)
y4=np.log10(x4)

print("第1個值=",y1)
print("第2個值=",y2)
print("第3個值=",y3)
print("第4個值=",y4)

# %% [markdown]
# ## **A05.試寫程式~完成以下的計算**
#
# ![m04.png](data:image/png;base64,...)

# %% [markdown]
# ## **A06.s i n 與 c o s 之疊合**

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(9,3),dpi=80)

pi=3.14159  # 圓周率
(A,B)=(2,1)  # 亦可自行修改

x=np.linspace(0,6*pi,1001) #(起點,終點,共幾個點包含端點)

y1=np.sin(x)
y2=np.cos(x)
y3=A*np.sin(x)+B*np.cos(x)

plt.plot(x,y1,color="blue",linewidth=2)
plt.plot(x,y2,color="green",linewidth=2)
plt.plot(x,y3,color="red",linewidth=4)

plt.show()

# %% [markdown]
# ## **A07.Making Waves 與波共舞**

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(9,12),dpi=80)

pi=3.14159 # 圓周率
x=np.linspace(0,6*pi,1001)

plt.subplot(4,1,1)    #作圖1
y1=np.sin(x)
plt.plot(x,y1,color="blue",linewidth=2)

plt.subplot(4,1,2)    #作圖2
y2=np.sin(2*x)
plt.plot(x,y2,color="blue",linewidth=2)

plt.subplot(4,1,3)    #作圖3
y3=np.sin(3*x)
plt.plot(x,y3,color="blue",linewidth=2)

plt.subplot(4,1,4)    #作圖4 合成波
y4=30*y1-80*y2+60*y3
plt.plot(x,y4,color="red",linewidth=4)

plt.show()

# %% [markdown]
# ## **A08.試寫程式~完成以下的圖形**
#
# ![m05.png](data:image/png;base64,...)

# %% [markdown]
# ## **A09.指數函數圖形**

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4),dpi=80)
plt.title("Example")   #標題名稱

x=np.linspace(-3,3,100)  #(起點,終點,共幾個點包含端點)
y1=2**x
y2=(1/2)**x

plt.plot(x,y1,color="red",linewidth=2)
plt.plot(x,y2,color="blue",linewidth=2)

plt.show()

# %% [markdown]
# ## **A10.試寫程式~完成對數函數圖形**

# %% [markdown]
# ## **A11.試將 A09 與 A10 程式~加入坐標軸**

# %% [markdown]
# ## **A12.試寫程式~完成指數與對數函數圖形(當底數大於1)**

# %% [markdown]
# ## **A13.試寫程式~完成指數與對數函數圖形(當底數小於1)**

# %% [markdown]
# ## **A14.試將 A12 與 A13 程式~再畫 直線 y=x**

# %% [markdown]
# ## **A15.試寫程式~**
#
# ![m07.png](data:image/png;base64,...)

# %% [markdown]
# ## **A16.試寫程式~**
#
# ![m06.png](data:image/png;base64,...)

# %% [markdown]
# # **單元 B 學習重點**
# *   **折線圖**
# *   **圓餅圖**

# %% [markdown]
# ## **B01.數據分析~折線圖 ( 函數資料 )**

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4),dpi=80)
plt.title("Example")   #標題名稱

x=np.linspace(-2,7,10) #(起點,終點,共幾個點包含端點)
y1=x**2-10
y2=x**2-20
y3=x**2-30
y4=x**2-40
y5=x**2-50

plt.plot(x,y1,marker="o",label="y=x*x-10")
plt.plot(x,y2,marker="^",label="y=x*x-20")
plt.plot(x,y3,marker="x",label="y=x*x-30")
plt.plot(x,y4,marker="s",label="y=x*x-40")
plt.plot(x,y5,marker="D",label="y=x*x-50")

plt.legend(loc="upper left") #展示每組數據對應的圖像名稱與位置
plt.show()

# %% [markdown]
# ## **B02.數據分析~折線圖 ( 離散資料 )**

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4),dpi=80)
plt.title("Tainan City") #標題名稱

x=["4/11","4/12","4/13","4/14","4/15"]
y1=[30,28,28,27,28]   #每天之最高溫度
y2=[24,22,22,22,22]   #每天之最低溫度

plt.plot(x,y1,marker="D",label="Highest temperature")
plt.plot(x,y2,marker="D",label="Lowest temperature")

plt.legend(loc="upper left") #展示每組數據對應的圖像名稱與位置
plt.ylim(15,35)              #設定 y 軸的範圍
plt.show()

# %% [markdown]
# ## **B03.將下列各組數據~做出其折線圖**
#
# ![m08.png](data:image/png;base64,...)

# %% [markdown]
# ## **B04.數據分析~圓餅圖 ( 離散資料 )**
#
# autopct='%2.1f%%'是用來顯示百分比

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,6),dpi=80)
plt.title("Example")  #標題名稱

x=[5,15,35,25,20]       #數量
name=["A","B","C","D","E"]  #項目
e=[0.01,0.01,0.15,0.01,0.01] #可以凸顯局部

plt.pie(x,labels=name,explode=e,autopct='%2.1f%%')
plt.show()

# %% [markdown]
# ## **B05.將下列數據~做出其圓餅圖**
#
# ![m09.png](data:image/png;base64,...)

# %% [markdown]
# # **單元 C 學習重點**
# *   **循環語句for**
# *   **序列資料與相關指令**
# *   **條件語句if**
# *   **有相同物的排列數**
# *   **塗色問題**

# %% [markdown]
# ## **C01.循環語句  for  (單層迴圈)**
# (有2種方法如下:)
#
# 要注意 **縮排與對齊**~非常重要

# %%
#用法1
#range(起點,終點,間隔) (包含起點,但不含終點)
for i in range(1,6,1):
    print(i,"的平方數=",i*i)
print("執行完畢")

# %%
#用法2
for i in [15,29,31,17,26]:
    print(i,"的平方數=",i*i)
print("執行完畢")

# %% [markdown]
# ## **C02.循環語句  for  (多層迴圈)**
#
# (有2種方法如下:)
#
# 要注意 **縮排與對齊**~非常重要

# %%
#用法1
for i in range(1,6,1):
    for j in range(1,6,1):
        print("(",i,",",j,")",end="") #不換行
    print(" ") #會換行
print("執行完畢")

# %%
#用法2
for i in ["無糖","微糖","多糖"]:
    for j in ["綠茶","紅茶","奶茶","花茶"]:
        print(i+j,end="  ")  #不換行
    print(" ")  #會換行
print("執行完畢")

# %% [markdown]
# ## **C03.試寫程式~**
# HW1.印出 "我以後上課不會打瞌睡" 10次
#
# HW2.印出等差數列前10項(首項為-5,公差為2)
#
# HW3.印出等比數列前10項(首項為-5,公比為2)
#
# HW4.印出九九乘法
#
# HW5.印出一副撲克牌
#
# HW6.印出投擲硬幣5次的樣本空間

# %% [markdown]
# ## **C04.序列資料與相關指令**

# %%
#要用中括弧括起來
A=[1,2,3,4,5,6,7,8,9]
B=["Tom","John","Peter","Donna"]
C=[]
print(A)
print(B)
print(C)

# %%
A=[1,2,3,4,5,6,7,8,9]
B=["Tom","John","Peter","Donna"]
C=[]
print(len(A)) #求個數
print(len(B)) #求個數
print(len(C)) #求個數

print(sum(A)) #求總和
print(max(A)) #求最大值
print(min(A)) #求最小值

# %%
B=["Tom","John","Peter","Donna"]
print(B[0])
print(B[1])
print(B[2])
print(B[3])

# %%
A=[1,2,3,4,5,6,7,8,9]
B=["Tom","John","Peter","Donna"]
C=[]
x=5
y="Mary"
z=100

A.remove(x) #移除x的值
B.append(y) #加入y的值
C.append(z) #加入z的值

print(A)
print(B)
print(C)

# %%
Ans=[1,1,1,2,3,4,5]
a=Ans.count(1) #求個數
b=Ans.count(2) #求個數
c=Ans.count(6) #求個數

print(a)
print(b)
print(c)

# %% [markdown]
# ## **C05.條件語句  if**

# %%
x=5  #請更改數字,觀察其效果為何
if(x>0):
  print(x,"是正數")

print("執行完畢")

# %% [markdown]
# ## **C06.有相同物的排列數**
# **題目:將2個紅球、3個黃球，排成一列，求其排列數**

# %%
A=["R","Y"]
Ans=[]
#設x,y,z,u,v分別為第1,2,3,4,5位置的顏色
for x in A:
 for y in A:
  for z in A:
   for u in A:
    for v in A:
     T=[x,y,z,u,v]  #暫時放置的序列
             #請完成程式碼
             #請完成程式碼
     if (2>1):   #請修改
       Ans.append(x+y+z+u+v)
print ("答案=",Ans)
print ("方法數=",len(Ans))

# %% [markdown]
# ## **C07.試寫程式~**
# HW1.將2個紅球、3個黃球、2個綠球，排成一列，求其排列數。
#
# HW2.由6個數字0,0,1,1,2,2 排成的六位數﹐共有多少個？

# %% [markdown]
# ## **C08.試寫程式~**
# HW3.
#
# 有a、b、c、d、e 等五人排一列，求下列各情況之排列數：
#
# (1)　a不排首位，b不排第二位。
#
# (2)　a不排首位，b不排第二位，c不排第三位

# %% [markdown]
# ## **C09.試寫程式~**
# HW4.
#
# 從 t o m a t o 的 6個字母中﹐任意選取 4 個排成一列﹐共有多少種排法﹖ 答:102

# %% [markdown]
# ## **C10.試寫程式~**
#
#
# ![m10.png](data:image/png;base64,...)

# %% [markdown]
# # **單元 D 學習重點**
# *   **柱狀圖**
# *   **隨機亂數**
# *   **數學期望值**

# %% [markdown]
# ## **D01.柱狀圖**

# %%
import matplotlib.pyplot as plt

x=["Tom","John","Peter","Mark","Donna"]  #各柱子的文字
y=[15, 20, 18, 25, 10]          #各柱子的高度
plt.bar(x,y,color="red",edgecolor="black",width=0.75,alpha=0.5)

plt.title("Example")   # 標題
plt.xlabel("Name")    # x 軸的文字
plt.ylabel("numbers")  # y 軸的文字
plt.show()

# %% [markdown]
# ## **D02.投擲1個公正骰子 1 次**

# %%
import random
S=[1,2,3,4,5,6]   #公正骰子的點數
a=random.choice(S)  #從袋子內取到的點數
print("投擲結果:",a)

# %% [markdown]
# ## **D03.投擲1個公正骰子 N 次**

# %%
import random
N=20        #投擲總數
S=[1,2,3,4,5,6]   #公正骰子的點數
Ans=[]       #儲存每次的點數

for i in range(1,N+1,1):
    a=random.choice(S)  #從袋子內取到的點數
    Ans.append(a)

print("投擲結果:",Ans)  #本指令為確認資料正確,事後可刪除

# %% [markdown]
# ## **D04.投擲1個公正骰子 N 次,並計算其次數**

# %%
import matplotlib.pyplot as plt
import numpy as np
y1=Ans.count(1)  #計算1的次數
y2=Ans.count(2)  #計算2的次數
y3=Ans.count(3)  #計算3的次數
y4=Ans.count(4)  #計算4的次數
y5=Ans.count(5)  #計算5的次數
y6=Ans.count(6)  #計算6的次數
x=[1,2,3,4,5,6]    #各柱子的文字
y=[y1,y2,y3,y4,y5,y6] 
plt.bar(x,y,width=0.75,color="green",edgecolor="black",alpha=0.5)

plt.title("Example")   # 標題
plt.xlabel("dice")    # x軸的文字
plt.ylabel("numbers")   # y軸的文字
plt.show()

# %% [markdown]
# ## **D05.計算數學期望值**

# %%
print("數學期望理論值=",3.5)
print("數學期望實驗值=",(1*y1+2*y2+3*y3+4*y4+5*y5+6*y6)/N)

# %% [markdown]
# ## **D06.試將D03,D04,D05合併**
#
# 請將程式做修飾,並以 N=10000 執行

# %% [markdown]
# ## **D07.試寫程式~**
# 同時投擲4個公正硬幣 N 次,若每出現1個正面可得100元﹐試以前頁範例的步驟完成柱狀圖與數學期望值.
#
# 提示 ~
#
# S=[0,100]
#
# a=random.choice(S)+random.choice(S)+random.choice(S)+random.choice(S)
