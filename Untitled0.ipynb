# %% [markdown]
# #課程名稱 : **數據統計與遞迴**
# ![m01.png](data:image/png;base64,...)
# ####上課須知
# * 請不要帶食物進教室.
# * 下課後,記得要登出,可以不用關機.

# %% [markdown]
# #適合Python初學者的雲端開發環境Google Colaboratory
# ####簡稱 Colab 是一個在雲端運行的編輯執行環境，由Google提供開發者虛擬機，並支援Python程式。只需要瀏覽器就可以運作，完全免費。
# ####程式碼預設會直接儲存在開發者的Google Drive雲端硬碟中，執行時由虛擬機提供強大的運算能力，不會用到本機的資源。但要注意在閒置一段時間後，虛擬機會被停止並回收運算資源，此時只需再重新連接即可。
#
#
# ![m02.png](data:image/png;base64,...)

# %%
#P1
#字串的方法(string methods)
A="Welcome to Tnssh!"
print(A.strip())
print(A.lower())
print(A.replace("e","x"))
print(A.split(","))
S="come" in A
print(S)
x="Hello!"
print(x+A)

# %%
#P2
#字串的方法(string methods)
A="Welcome to Tnssh!"
print(A.index("Tnssh"))
print(A.find("m"))
print(A.count('e'))
print(A[:-3])
print(' '.join(reversed(A)))
print(A.isalnum())

# %%
#P3
#python的字串相關功能
#把「值」變成字串
str(232)
str(False)

#回傳字元的Unicode碼
ord("b")

#回傳整數對應的Unicode字元
chr(65)

# %%
#P4
#從Python3.6開始，f-string(F字符串)是格式化字符串
#的一種很好的新方法。與其他格式化方式相比，它們不
#僅更易讀，更簡潔，不易出錯，而且速度更快！
#f-strings 也稱作「格式化的字符串字面量」，它是
#一個帶有 f 前綴的字符串，通過大括號嵌入所需的
# python 表達式

# %%
#P5
a = 1
b = 2
c = 3
print(f"a={i1};b={i2};c={i3}")

# %%
#P6
'''
#範例: 兔兔的罰寫作業一百遍
話說在可愛動物程式學園中，
兔兔因為上課偷睡覺被馬老師抓到，
馬老師決定讓兔兔罰抄「我以後上課不會打瞌睡」一百遍。

馬老師給兔兔兩個選擇，

用手抄一百遍
由於是程式學園，改以在螢幕上顯示一百遍「我以後上課不會打瞌睡」
'''

# %%
N=10
for i in range(1,N+1,1):
    print('我以後上課不會打瞌睡')

# %% [markdown]
# #範例: 兔兔的罰寫作業一百遍
# 話說在可愛動物程式學園中，
# 兔兔因為上課偷睡覺被馬老師抓到，
# 馬老師決定讓兔兔罰抄「我以後上課不會打瞌睡」一百遍。
#
# 馬老師給兔兔兩個選擇，
#
# 用手抄一百遍
# 由於是程式學園，改以在螢幕上顯示一百遍「我以後上課不會打瞌睡」

# %% [markdown]
# #<續集>
# 這時馬老師來檢查兔兔的螢幕，
# 馬老師說「這樣不行，我怎麼知道螢幕上是不是真的有一百遍文字呢?難道要我一行一行數嗎?」
# 馬老師要求在每句的「我以後上課不會打瞌睡」前面要加上編號，
# 在螢幕上要顯示
# 1. 我以後上課不會打瞌睡
# 2. 我以後上課不會打瞌睡
# …
# 100. 我以後上課不會打瞌睡
# 這樣子才一目瞭然
#
# 聰明如你，幫兔兔想想辦法程式要怎麼改寫呢?

# %%
N=10
for i in range(1,N+1,1):
    print(f'{i}.我以後上課不會打瞌睡')
# Out:
# 1.我以後上課不會打瞌睡
# 2.我以後上課不會打瞌睡
# 3.我以後上課不會打瞌睡
# 4.我以後上課不會打瞌睡
# 5.我以後上課不會打瞌睡
# 6.我以後上課不會打瞌睡
# 7.我以後上課不會打瞌睡
# 8.我以後上課不會打瞌睡
# 9.我以後上課不會打瞌睡
# 10.我以後上課不會打瞌睡

# %% [markdown]
# #範例:用程式印出九九乘法表

# %%
N=9
for i in range(1,N+1,1):
  for j in range(1,N+1,1):
    print(f'{i}*{j}={i*j:2d}',end="  ")
  print(" ")

# %% [markdown]
# 從Python3.6開始，f-string(F字符串)是格式化字符串的一種很好的新方法。與其他格式化方式相比，它們不僅更易讀，更簡潔，不易出錯，而且速度更快！
# f-strings 也稱作「格式化的字符串字面量」，它是一個帶有 f 前綴的字符串，通過大括號嵌入所需的 python 表達式

# %% [markdown]
# #https://ithelp.ithome.com.tw/articles/10230759
